# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
#  Explore the dataset and identify the number
#  of rows and columns.

# %%
data = pd.read_csv(r"C:\Users\karun\Downloads\portfolio project 1\Cognifyz  internship\Dataset .csv")
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
#  Check for missing values in each column and
#  handle them accordingly.

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
data1 = pd.DataFrame(data)
data1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
print(data1['Restaurant ID'])
# Out:
# 0       6317637
# 1       6304287
# 2       6300002
# 3       6318506
# 4       6314302
#          ...
# 9546    5915730
# 9547    5908749
# 9548    5915807
# 9549    5916112
# 9550    5927402
# Name: Restaurant ID, Length: 9551, dtype: int64

# %%
print(data1['Country Code'].unique())
# Out:
# [162  30 216  14  37 184 214   1  94 148 215 166 189 191 208]

# %%
Rating_by_Country = data1[data1['Country Code']==162]['Aggregate rating']
print(Rating_by_Country)
# Out:
# 0     4.8
# 1     4.5
# 2     4.4
# 3     4.9
# 4     4.8
# 5     4.4
# 6     4.0
# 7     4.2
# 8     4.9
# 9     4.8
# 10    4.9
# 11    4.2
# 12    4.8
# 13    4.2
# 14    4.3
# 15    3.6
# 16    4.0
# 17    4.5
# 18    4.5
# 19    4.4
# 20    4.7
# 21    4.5
# Name: Aggregate rating, dtype: float64

# %%
Rating_by_Country2 = data1[data1['Country Code']==30]['Aggregate rating']
print(Rating_by_Country2)
# Out:
# 22    3.0
# 23    3.8
# 24    3.7
# 25    3.8
# 26    3.2
# 27    3.1
# 28    3.7
# 29    3.7
# 30    0.0
# 31    4.1
# 32    3.1
# 33    3.6
# 34    4.3
# 35    4.2
# 36    3.6
# 37    4.0
# 38    3.2
# 39    4.9
# 40    3.3
# 41    3.6
# 42    4.0
# 43    4.8
# 44    4.7
# 45    4.5
# 46    4.2
# 47    4.8
# 48    4.9
# 49    4.6
# 50    4.9
# 51    4.6
# 52    4.3
# 53    4.0
# 54    4.6
# 55    4.4
# 56    4.2
# 57    4.2
# 58    0.0
# 59    4.7
# 60    4.6
# 61    4.3
# 62    4.5
# 63    4.4
# 64    3.1
# 65    4.1
# 66    4.8
# 67    4.6
# 68    3.9
# 69    0.0
# 70    3.4
# 71    3.5
# 72    4.3
# 73    3.9
# 74    4.3
# 75    4.3
# 76    4.4
# 77    0.0
# 78    0.0
# 79    4.4
# 80    4.6
# 81    4.1
# Name: Aggregate rating, dtype: float64

# %%
data1['Aggregate rating'].median()
# Out:
# 3.2

# %%
rating_col = data1['Aggregate rating']
rating_col.replace(to_replace=0,value = rating_col.median(),inplace=True)

# %%
rating_col.unique()
# Out:
# array([4.8, 4.5, 4.4, 4.9, 4. , 4.2, 4.3, 3.6, 4.7, 3. , 3.8, 3.7, 3.2,
#        3.1, 4.1, 3.3, 4.6, 3.9, 3.4, 3.5, 2.2, 2.9, 2.4, 2.6, 2.8, 2.1,
#        2.7, 2.5, 1.8, 2. , 2.3, 1.9])

# %%
data1['Aggregate rating'].mean()
# Out:
# 3.386043346246467

# %%
data1['Aggregate rating'].std()
# Out:
# 0.4963668608290476

# %%
data1['Aggregate rating'].describe()
# Out:
# count    9551.000000
# mean        3.386043
# std         0.496367
# min         1.800000
# 25%         3.100000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
data2 = np.random.randn(1000)
plt.hist(data1['Aggregate rating'], bins=10,color='green',edgecolor='black')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Descriptive Analysis')
plt.show()

# %%
class_counts=data1['Aggregate rating'].value_counts()
print(class_counts)
# Out:
# Aggregate rating
# 3.2    2670
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: count, dtype: int64

# %% [markdown]
#  Calculate basic statistical measures (mean,
#  median, standard deviation, etc.) for numerical
#  columns.

# %%
data1['Price range'].describe()
# Out:
# count    9551.000000
# mean        1.804837
# std         0.905609
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         4.000000
# Name: Price range, dtype: float64

# %%
data1['Votes'].describe()
# Out:
# count     9551.000000
# mean       156.909748
# std        430.169145
# min          0.000000
# 25%          5.000000
# 50%         31.000000
# 75%        131.000000
# max      10934.000000
# Name: Votes, dtype: float64

# %%
data1['Average Cost for two'].describe()
# Out:
# count      9551.000000
# mean       1199.210763
# std       16121.183073
# min           0.000000
# 25%         250.000000
# 50%         400.000000
# 75%         700.000000
# max      800000.000000
# Name: Average Cost for two, dtype: float64
